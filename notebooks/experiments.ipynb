# %% [markdown]
# # Comparison of Standardization Methods
#
# Evaluate and compare four methods side-by-side on auto-discovered Unitxt datasets:
# - **Keyword baseline** — rule-based synonym matching
# - **Embedding baseline** — cosine similarity via `all-MiniLM-L6-v2`
# - **Local LLM** — `Qwen/Qwen3-0.6B` running locally
# - **API LLM** — `claude-opus-4.6` via OpenRouter

# %% [markdown]
# ## 1. Imports & Setup

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))

import logging
logging.getLogger("unitxt").setLevel(logging.ERROR)

from module import discover_datasets, run_evaluation, show_tables, plot_results

print("Imports OK")
# Out:
# Imports OK

# %%
import os
os.environ["OPENROUTER_API_KEY"] = "your_key_here"  # replace before running

# %% [markdown]
# ## 2. Discover Datasets

# %%
# Choose which task families to include — comment out any you don't want
datasets = discover_datasets(task_types=[
    "classification",
    "nli",
    "qa",
    "generation",
])

print(f"Found {len(datasets)} datasets")
for d in datasets:
    cfg = f"  config={d['hf_config']}" if d["hf_config"] else ""
    print(f"  [{d['card_id']:40s}  hf={d['hf_name']}{cfg}")
# Out:
# Found 3057 datasets
#   [20_newsgroups                             hf=SetFit/20_newsgroups
#   [20_newsgroups_short                       hf=SetFit/20_newsgroups
#   [ag_news                                   hf=fancyzhx/ag_news
#   [ai2d                                      hf=lmms-lab/ai2d
#   [almost_evil                               hf=0x22almostEvil/multilingual-wikihow-qa-16k
#   [argument_topic                            hf=ibm/argument_quality_ranking_30k  config=argument_topic
#   [banking77                                 hf=PolyAI/banking77
#   [billsum                                   hf=billsum
#   [billsum_document_filtered_to_10000_chars  hf=billsum
#   [billsum_document_filtered_to_6000_chars   hf=billsum
#   [chart_qa                                  hf=HuggingFaceM4/ChartQA
#   [chart_qa_lmms_eval                        hf=lmms-lab/ChartQA
#   [claim_stance_topic                        hf=ibm/claim_stance  config=claim_stance_topic
# ...

# %% [markdown]
# ## 3. Run Evaluation

# %%
df_results = run_evaluation(datasets=datasets[:10])
# Out:
# 10 datasets  x  4 methods  =  40 evaluations
#
# ── 20_newsgroups ──
#   keyword... Mapping: {'text': 'text', 'label': 'label', 'task': 'classification'}
#   score=0.200  struct=0.400  annot=0.000
#   embedding... Mapping: {'text': 'text', 'label': 'label', 'text_a': 'text', 'text_b': 'text', 'task': 'nli'}
#   score=0.143  struct=0.286  annot=0.000
#   local_llm... Loading local model 'Qwen/Qwen3-0.6B' (first call only)…
# Local model loaded.
# Mapping: {'task': 'classification', 'text': 'text', 'text_type': 'sentence', 'classes': ['rec.autos', 'comp.sys.mac.hardware', 'comp.graphics', 'sci.space'], 'type_of_class': 'entailment', 'label': 'label'} (score: 1.00)
# Mapping: {'task': 'classification', 'text': 'text', 'text_type': 'sentence', 'classes': ['rec.autos', 'comp.sys.mac.hardware', 'comp.graphics', 'sci.space'], 'type_of_class': 'entailment', 'label': 'label'}
#   score=0.500  struct=1.000  annot=0.000
# ...

# %% [markdown]
# ## 4. Results Table

# %%
show_tables(df_results)
# Out:
# === Combined score  (struct + annot) / 2 ===
# method                                    keyword  embedding  local_llm  \
# dataset
# 20_newsgroups                                0.20      0.143       0.50
# 20_newsgroups_short                          0.20      0.143       0.50
# ag_news                                      0.20      0.143       0.50
# ai2d                                         0.00      0.167       0.00
# almost_evil                                  0.50      0.500       0.50
# argument_topic                               0.20      0.143       0.50
# banking77                                    0.20      0.143       0.00
# billsum                                      0.00      0.000       0.00
# billsum_document_filtered_to_10000_chars     0.00      0.000       0.00
# billsum_document_filtered_to_6000_chars      0.00      0.000       0.00
# Average                                      0.15      0.138       0.25
#
# ...

# %% [markdown]
# ## 5. Visualization

# %%
plot_results(df_results)
